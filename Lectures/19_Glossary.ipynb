# %% [markdown]
# # Glossary
#
#
# \begin{array}{l l }
# \text{accuracy} & \\
# \text{bandwidth} & \\
# \text{capacity} &  \\
# \text{cutoff frequency} & \\
# \text{data} & \\
# \text{distortion} & \\
# \text{error} & \\
# \text{filter} & \\
# \text{frequency} & \text{radial/angular frequency vs frequency} \\
# \text{inertia} & \\
# \text{information} & \\
# \text{knowledge} & \\
# \text{precision} & \\
# \text{pseudo-static} & \\
# \text{random} & \\
# \text{resolution} & \text{The smallest change or increment in the measured quantity that the instrument can detect.  For digital instrument, the resolution is associated with the number of digits.} \\
# \text{sensitivity} & \text{Also called process gain.  It is the change in the output $y$ induced by a unit change in the input $x$.}\\
# \text{static} & \\
# \text{steady-state} & \\
# \text{time constant} & \text{Time necessary for system to reach steady state.}\\
# \text{transient} & \\
# \text{uncertainty} & \\
# \text{wisdom} & \\
# \end{array}
